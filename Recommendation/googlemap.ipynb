# %%
import requests

url = "https://maps.googleapis.com/maps/api/place/textsearch/json?query=restaurants%20in%20Sydney&key=AIzaSyBZuIZi_OblHYl6n0dwX40W_5Harpp6wlk"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {
#    "html_attributions" : [],
#    "next_page_token" : "Aap_uEAzGxHwlieDLeP3ZIA-VFx_owXXLAFqZkC2FDgrjPTrmxkEfbGraZlY4qEHcVhBXAYuM9ECuWAZLZL_cPkgIBa1hJ25ANiUiUgpeP9T-81UzmWvvjm9FNLTRpHw29rLpI6NrbPG6UsrjojFVyrqPqVvFknboUuNdNV1Y703tLHUyC4zEM49f7ZB6WxZz4rQN7mEglP46N9E6XbmJxF9jJIr7SpeAUUbADDgTB1wsvuzQ5yYPwhmaAKntcXmiC6mCRDEUycHt0vp-FVaXh_mX6Pav_ggVu-l9eeHK4ivDT5-OKYjRNS0xR43xaG6nFIpU1EPYHyk6eQ5nBhN3fxKOLrBJ1hBF_4iecoKaOAVFstbwMzznHXKX_hWz882zalo6bCxIR-wJncRoVQv3gFuNGuvnw",
#    "results" : [
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "1 Macquarie St, Sydney NSW 2000, Australia",
#          "geometry" : {
#             "location" : {
#                "lat" : -33.8592041,
#                "lng" : 151.2132635
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : -33.85786707010728,
#                   "lng" : 151.2147093298927
#                },
#                "southwest" : {
# ...

# %%
# Find lat&log for zipcode = 10025
url = 'https://maps.googleapis.com/maps/api/geocode/json?address=10025&key=AIzaSyBZuIZi_OblHYl6n0dwX40W_5Harpp6wlk'

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "10025",
#                "short_name" : "10025",
#                "types" : [ "postal_code" ]
#             },
#             {
#                "long_name" : "Manhattan",
#                "short_name" : "Manhattan",
#                "types" : [ "political", "sublocality", "sublocality_level_1" ]
#             },
#             {
#                "long_name" : "New York",
#                "short_name" : "New York",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "New York County",
#                "short_name" : "New York County",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "New York",
#                "short_name" : "NY",
#                "types" : [ "administrative_area_level_1", "political" ]
# ...

# %%
import requests
url = 'https://maps.googleapis.com/maps/api/geocode/json?address=10025&key=AIzaSyBZuIZi_OblHYl6n0dwX40W_5Harpp6wlk'

payload={}
headers = {}

response = requests.get(url)

resp_json_payload = response.json()

loc = resp_json_payload['results'][0]['geometry']['location']
loc['lat'] -1
# Out:
# 39.7999209

# %%
df.business_status.unique()
# Out:
# array(['OPERATIONAL'], dtype=object)

# %%
# Find hotel on zipcode:10025
url = "https://maps.googleapis.com/maps/api/place/textsearch/json?location=40.7999209%2C-73.96831019999999&radius=500&type=lodging&key=AIzaSyBZuIZi_OblHYl6n0dwX40W_5Harpp6wlk"

payload={}
headers = {}

response = requests.get(url)

resp_json_payload = response.json()
# response = requests.request("GET", url, headers=headers, data=payload)

# print(response.text)

# %%
df = pd.json_normalize(resp_json_payload['results'])

# %%
new_col = [name.replace(".","_") for name in list(df.columns)]

# %%
df.set_axis(new_col,axis = 1, inplace = True)

# %%
df
# Out:
#    business_status  ... plus_code_global_code
# 0      OPERATIONAL  ...           87G8R35C+X8
# 1      OPERATIONAL  ...           87G8R3J9+M9
# 2      OPERATIONAL  ...           87G8Q2XM+F8
# 3      OPERATIONAL  ...           87G8R234+4Q
# 4      OPERATIONAL  ...           87G8R37C+4M
# 5      OPERATIONAL  ...           87G8R2CF+9Q
# 6      OPERATIONAL  ...           87G8Q2XW+WH
# 7      OPERATIONAL  ...           87G8Q288+7P
# 8      OPERATIONAL  ...           87G8R356+5X
# 9      OPERATIONAL  ...           87G8Q388+JG
# 10     OPERATIONAL  ...           87G8Q298+73
# 11     OPERATIONAL  ...           87G8R333+QH
# 12     OPERATIONAL  ...           87G8Q2XQ+6J
# 13     OPERATIONAL  ...           87G8R3CC+MQ
# 14     OPERATIONAL  ...           87G8R355+J5
# 15     OPERATIONAL  ...           87G8R3C2+W5
# 16     OPERATIONAL  ...           87G8Q3Q2+QG
# 17     OPERATIONAL  ...           87G8R25W+M7
# 18     OPERATIONAL  ...           87G8R332+R9
# ...

# %%
df.to_gbq('finalproject.testHotel', project_id='big-data-6893-326923', if_exists='replace',progress_bar=True)
# Out:
# 1it [00:02,  2.93s/it]

# %%
from google.colab import auth
auth.authenticate_user()

# %%
len(resp_json_payload["results"])
# Out:
# 20

# %%
import requests
import pandas as pd
import time
url = "https://maps.googleapis.com/maps/api/place/textsearch/json?location=40.7999209%2C-73.96831019999999&radius=50000&type=meal_takeaway&hasNextPage=true&nextPage()=true&sensor=false&key=AIzaSyBZuIZi_OblHYl6n0dwX40W_5Harpp6wlk"

payload={}
headers = {}

response = requests.get(url)

resp_json_payload = response.json()

# %%
df=pd.json_normalize(resp_json_payload["results"])
while "next_page_token" in resp_json_payload:
  time.sleep(3)
  page2_token = resp_json_payload["next_page_token"]        
  print(page2_token)
  url="https://maps.googleapis.com/maps/api/place/textsearch/json?location=40.7999209%2C-73.96831019999999&radius=50000&type=meal_takeaway&pagetoken="+page2_token+"&key=AIzaSyBZuIZi_OblHYl6n0dwX40W_5Harpp6wlk"
  response = requests.get(url)
  resp_json_payload = response.json()
  print(resp_json_payload["status"])
  df2=pd.json_normalize(resp_json_payload["results"])
  print(len(df2))
  df = pd.concat([df,df2])

# %%
len(df)
# Out:
# 15

# %%
url = "https://maps.googleapis.com/maps/api/place/textsearch/json?location=40.7999209%2C-73.96831019999999&radius=50000&type=cafe&hasNextPage=true&nextPage()=true&sensor=false&key=AIzaSyBZuIZi_OblHYl6n0dwX40W_5Harpp6wlk"

payload={}
headers = {}

response = requests.get(url)

resp_json_payload = response.json()

# %%
df2=pd.json_normalize(resp_json_payload["results"])
df = pd.concat([df,df2])

while "next_page_token" in resp_json_payload:
  time.sleep(3)
  page2_token = resp_json_payload["next_page_token"]        
  print(page2_token)
  url="https://maps.googleapis.com/maps/api/place/textsearch/json?location=40.7999209%2C-73.96831019999999&radius=50000&type=cafe&pagetoken="+page2_token+"&key=AIzaSyBZuIZi_OblHYl6n0dwX40W_5Harpp6wlk"
  response = requests.get(url)
  resp_json_payload = response.json()
  print(resp_json_payload["status"])
  df2=pd.json_normalize(resp_json_payload["results"])
  print(len(df2))
  df = pd.concat([df,df2])
# Out:
# Aap_uEDhU5H0od9a0qu5u-QiDvw6RWOwMwABp0dJi4_27ef9vaGBlT_r143Y4_zR67Xpaf46yqYW3peoaK8hkiWjgViDNdUTgTETjeHkcbRNfRmgkBbKXVw2cYn5LA6QJXLnJBCmy20Ca4bH5Y3aXZuiK0w9AUF63WOvNvhc0MogxwtgMe7MKn7SkyK0O2q14CxpJxax2T5gIdYAmdxd0g2WyCf4-M57gDxLwVQz10Q9SZwWfQUhSHAwkTPGDqrIioR5N04ZEmZLZiF3wWUXv-ENbc5xJsF1DyWpMQsEyKS81E48mk_lpVDlukenrC2xr1Q5NPg5lEGN213gDnbZTSM_0VMWqvtmeAkyAXiLrm1O2PLigy7FQSjos_M4kVAMmE1jDE0rfLQSxxANEKTW-psqJgCOdjQDhABgCXU0zkYluzgWHYmcTvxB6OOfI7s
# OK
# 20
# ...

# %%
len(df)
# Out:
# 120

# %%
len(df.place_id.unique())
# Out:
# 120

# %%
len(df.place_id.unique())
# Out:
# 120

# %%
url = "https://maps.googleapis.com/maps/api/place/textsearch/json?location=40.7999209%2C-73.96831019999999&radius=5000&type=cafe&key=AIzaSyBZuIZi_OblHYl6n0dwX40W_5Harpp6wlk"

payload={}
headers = {}

response2 = requests.get(url)

resp_json_payload2 = response2.json()

# %%
resp_json_payload
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uECLikCld7HqjDQ_paycY_hhAxIOFKZtH2Zn1Z7eMM7M3onu9JDPyGbPU2VSBCeUVXM_uhGcgKP4-hnHckVGa_aPILA4IiGjF5WsMgjaSGWGdy16W3GLRY_PcUCKl3pJabjEYNg06qagU4li9CoXUWVN6iFqvcFyVen4tmkdO6nU_8w8jrU_0AbU7dPBZPjeCTXQwBKa3dzbcuCklBbUTjTqqCa3goJk3_RtkyCB_3Kz3FwtUSRb6A7vcj-gICdc2r-PSMN3uspIc9hsjCNi2KGSWCOx2hW1fydZhQR9NN5rMtiroJvKVXyWX2e_b3P67WSIJS4KCHFypTYUlGEN8NAi0aY2xIBkiAY0KSJpyh-KS-uAtLQKgD1XXlJTDfYE26F8LA_v78pHELPPibkRp8TEpfBVd1QCUrl-_6xRShuQiIhizF97BWTDaCyTfQ',
#  'results': [{'business_status': 'OPERATIONAL',
#    'formatted_address': '36-01 35th Ave, Queens, NY 11106',
#    'geometry': {'location': {'lat': 40.7563454, 'lng': -73.9239496},
#     'viewport': {'northeast': {'lat': 40.75755497989272,
#       'lng': -73.92267382010728},
#      'southwest': {'lat': 40.75485532010727, 'lng': -73.92537347989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/museum-71.png',
#    'icon_background_color': '#13B5C7',
# ...

# %%
df = pd.json_normalize(resp_json_payload["results"])
df
# Out:
#        business_status  ... permanently_closed
# 0          OPERATIONAL  ...                NaN
# 1          OPERATIONAL  ...                NaN
# 2          OPERATIONAL  ...                NaN
# 3          OPERATIONAL  ...                NaN
# 4          OPERATIONAL  ...                NaN
# 5   CLOSED_TEMPORARILY  ...               True
# 6          OPERATIONAL  ...                NaN
# 7          OPERATIONAL  ...                NaN
# 8          OPERATIONAL  ...                NaN
# 9          OPERATIONAL  ...                NaN
# 10         OPERATIONAL  ...                NaN
# 11         OPERATIONAL  ...                NaN
# 12  CLOSED_TEMPORARILY  ...               True
# 13         OPERATIONAL  ...                NaN
# 14         OPERATIONAL  ...                NaN
# 15  CLOSED_TEMPORARILY  ...               True
# 16         OPERATIONAL  ...                NaN
# 17         OPERATIONAL  ...                NaN
# 18         OPERATIONAL  ...                NaN
# ...

# %%
df2 = pd.json_normalize(resp_json_payload2["results"])
df2
# Out:
#        business_status  ... permanently_closed
# 0          OPERATIONAL  ...                NaN
# 1          OPERATIONAL  ...                NaN
# 2   CLOSED_TEMPORARILY  ...               True
# 3          OPERATIONAL  ...                NaN
# 4          OPERATIONAL  ...                NaN
# 5          OPERATIONAL  ...                NaN
# 6          OPERATIONAL  ...                NaN
# 7          OPERATIONAL  ...                NaN
# 8          OPERATIONAL  ...                NaN
# 9          OPERATIONAL  ...                NaN
# 10         OPERATIONAL  ...                NaN
# 11         OPERATIONAL  ...                NaN
# 12         OPERATIONAL  ...                NaN
# 13         OPERATIONAL  ...                NaN
# 14         OPERATIONAL  ...                NaN
# 15         OPERATIONAL  ...                NaN
# 16         OPERATIONAL  ...                NaN
# 17         OPERATIONAL  ...                NaN
# 18         OPERATIONAL  ...                NaN
# ...

# %%
df.columns
# Out:
# Index(['business_status', 'formatted_address', 'icon', 'icon_background_color',
#        'icon_mask_base_uri', 'name', 'photos', 'place_id', 'rating',
#        'reference', 'types', 'user_ratings_total', 'geometry.location.lat',
#        'geometry.location.lng', 'geometry.viewport.northeast.lat',
#        'geometry.viewport.northeast.lng', 'geometry.viewport.southwest.lat',
#        'geometry.viewport.southwest.lng', 'opening_hours.open_now',
#        'plus_code.compound_code', 'plus_code.global_code', 'price_level',
#        'permanently_closed'],
#       dtype='object')

# %%
len(df)
# Out:
# 20

# %%
df2.columns
# Out:
# Index(['business_status', 'formatted_address', 'icon', 'icon_background_color',
#        'icon_mask_base_uri', 'name', 'photos', 'place_id', 'rating',
#        'reference', 'types', 'user_ratings_total', 'geometry.location.lat',
#        'geometry.location.lng', 'geometry.viewport.northeast.lat',
#        'geometry.viewport.northeast.lng', 'geometry.viewport.southwest.lat',
#        'geometry.viewport.southwest.lng', 'opening_hours.open_now',
#        'plus_code.compound_code', 'plus_code.global_code', 'price_level',
#        'permanently_closed'],
#       dtype='object')

# %%
len(df2)
# Out:
# 20

# %%
df3 = pd.concat([df,df2])
len(df3)
# Out:
# 40

# %%
len(df3.place_id.unique())
# Out:
# 40

# %%
len(df)
# Out:
# 20

# %%
key = "AIzaSyBZuIZi_OblHYl6n0dwX40W_5Harpp6wlk"
food_lst = ["bakery"]

# %%
def Zip2Loc(zip):
  """convert zipcode to lat ang lng"""
  # Input:
  # zip: string or int, key: string
  # Output:
  # location dictionary: {"lat":float, "lng":float}
  url = 'https://maps.googleapis.com/maps/api/geocode/json?address='+str(zip)+'&key='+key
  response = requests.get(url)
  resp_json_payload = response.json()
  return resp_json_payload['results'][0]['geometry']['location']
def searchFood(zip,r):
  loc = Zip2Loc(zip)
  df = pd.DataFrame()
  for food in food_lst:
    url = "https://maps.googleapis.com/maps/api/place/textsearch/json?location="+\
            str(loc["lat"])+"%2C"+str(loc["lng"])+"&radius="+\
            str(r)+"&type="+food+"&businessstatus=operational&hasNextPage=true&nextPage()=true&sensor=false&key="+key
    response = requests.get(url)
    resp_json_payload = response.json()
    if df.empty:
      df = pd.json_normalize(resp_json_payload["results"])  
    else:
      df2 = pd.json_normalize(resp_json_payload["results"])
      df = pd.concat([df,df2])
    while "next_page_token" in resp_json_payload:
      time.sleep(3)
      page2_token = resp_json_payload["next_page_token"]        
      url="https://maps.googleapis.com/maps/api/place/textsearch/json?location=40.7999209%2C-73.96831019999999&radius="+\
          str(r)+"&type="+food+"&businessstatus=operational&pagetoken="+page2_token+"&key=AIzaSyBZuIZi_OblHYl6n0dwX40W_5Harpp6wlk"
      response = requests.get(url)
      resp_json_payload = response.json()

      df2 = pd.json_normalize(resp_json_payload["results"])
      df = pd.concat([df,df2])
  return df.drop_duplicates("place_id")

# %%
df = searchFood("10025", 5000)

# %%
df.business_status.unique()
# Out:
# array(['OPERATIONAL', 'CLOSED_TEMPORARILY'], dtype=object)

# %%
df
# Out:
#        business_status  ... permanently_closed
# 0          OPERATIONAL  ...                NaN
# 1          OPERATIONAL  ...                NaN
# 2          OPERATIONAL  ...                NaN
# 3          OPERATIONAL  ...                NaN
# 4          OPERATIONAL  ...                NaN
# 5          OPERATIONAL  ...                NaN
# 6          OPERATIONAL  ...                NaN
# 7          OPERATIONAL  ...                NaN
# 8          OPERATIONAL  ...                NaN
# 9          OPERATIONAL  ...                NaN
# 10         OPERATIONAL  ...                NaN
# 11         OPERATIONAL  ...                NaN
# 12         OPERATIONAL  ...                NaN
# 13         OPERATIONAL  ...                NaN
# 14         OPERATIONAL  ...                NaN
# 15         OPERATIONAL  ...                NaN
# 16         OPERATIONAL  ...                NaN
# 17         OPERATIONAL  ...                NaN
# 18         OPERATIONAL  ...                NaN
# ...

# %%
df[df.business_status == 'CLOSED_TEMPORARILY']
# Out:
#        business_status  ... permanently_closed
# 19  CLOSED_TEMPORARILY  ...               True
# 7   CLOSED_TEMPORARILY  ...               True
# 12  CLOSED_TEMPORARILY  ...               True
#
# [3 rows x 23 columns]

# %%
import requests
url = "https://data.xotelo.com/api/rates?hotel_key=g48080-d23701786&chk_in=2021-11-29&chk_out=2021-11-30"
payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"result":{"chk_in":"2021-11-29","chk_out":"2021-11-30","currency":"USD","rates":[{"code":"Agoda","name":"Agoda.com","rate":71.0,"tax":14.0},{"code":"HotelsCom2","name":"Hotels.com","rate":71.0,"tax":14.0}],"hotel_url":["http:\/\/www.tripadvisor.com\/Hotel_Review-g48080-d23701786-Reviews-Manhattan_View_Hotel-Long_Island_City_Queens_New_York.html","23701786"]},"error":null,"timestamp":1638123558.7225620747,"message":"Please support me on https:\/\/xotelo.com\/donate.html"}

# %%
hotel = []
for name in bsobj.findAll('div',{'class':'listing_title'}):
  hotel.append(name.text.strip())

# %%
import requests
from bs4 import BeautifulSoup
import math, time

# BASE_URL = 'https://www.tripadvisor.com/Hotels-g187471-Gran_Canaria_Canary_Islands-Hotels.html'
BASE_URL = 'https://www.tripadvisor.in/Hotels-g60763-New_York_City_New_York-Hotels.html'
PER_PAGE = 30

response = requests.get(BASE_URL).text
soup = BeautifulSoup(response)
span = soup.select('.MOBILE_SORT_FILTER_BUTTONS + div span')[0]
N_PROPERTIES = int(re.sub('([^0-9\.])', '', span.text))
print(f'There are {N_PROPERTIES} properties')
N_PAGES = math.ceil(N_PROPERTIES / PER_PAGE)
print(f'There are {N_PAGES} different pages')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-6cfedce56379> in <module>()
#       7 PER_PAGE = 30
#       8
# ----> 9 response = requests.get(BASE_URL).text
#      10 soup = BeautifulSoup(response)
#      11 span = soup.select('.MOBILE_SORT_FILTER_BUTTONS + div span')[0]
#
# ...

# %%
def get_id_from_url(URL):
  # Split URL by -g to divide it before the ID
  prefix, suffix = url.split('-g', maxsplit=1)
  # Divide the URL after the ID (first dash)
  id, slug = suffix.split('-', maxsplit=1)
  return int(id)

def get_listing_url(page, base_url=BASE_URL, per_page=PER_PAGE):
  assert page >= 0
  id = get_id_from_url(base_url)
  if page == 0:
    return BASE_URL

  return BASE_URL.replace(f'-g{id}-', f'-g{id}-oa{page * per_page}-')

# %%
import requests

url = "https://hotels4.p.rapidapi.com/properties/get-details"

querystring = {"id":"1168574848","checkIn":"2022-01-08","checkOut":"2022-01-10","adults1":"1","currency":"USD","locale":"en_US"}

headers = {
    'x-rapidapi-host': "hotels4.p.rapidapi.com",
    'x-rapidapi-key': "9bd3146f2fmsh683867edab2caa3p13a885jsn3ee24bfa5443"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"result":"OK","data":{"body":{"pdpHeader":{"hotelId":"1168574848","destinationId":"1527530","pointOfSaleId":"HCOM_US","currencyCode":"USD","occupancyKey":"A1","hotelLocation":{"coordinates":{"latitude":40.7577,"longitude":-73.9385},"resolvedLocation":"CITY:1527530:PROVIDED:PROVIDED","locationName":"Long Island City"}},"overview":{"overviewSections":[{"title":"Main amenities","type":"HOTEL_FEATURE","content":["120 smoke-free guestrooms","Daily housekeeping","Fitness center","24-hour front desk","Air conditioning","Computer station","Banquet hall","Free WiFi "],"contentType":"LIST"},{"title":"What’s around","type":"LOCATION_SECTION","content":["In Queens","Roosevelt Island - 30 min walk","Memorial Sloan-Kettering Cancer Center - 2.5 mi / 4 km","5th Avenue - 2.6 mi / 4.3 km","Hospital for Special Surgery - 2.8 mi / 4.5 km","United Nations Headquarters - 2.9 mi / 4.6 km","Central Park Zoo - 3.1 mi / 5 km","Museum of Modern Art - 3.1 mi / 5 km","St. Patrick's Cathedral - 3.1 mi / 5 km","
# ...

# %%
total = response.json()
total["data"]["body"]["roomsAndRates"]["rooms"]
# Out:
# [{'additionalInfo': {'description': '<p><strong>1 Queen Bed</strong></p><p>250 sq feet </p><br/><p><b>Internet</b> - Free WiFi </p><p><b>Food & Drink</b> - Refrigerator</p><p><b>Sleep</b> - Bed sheets </p><p><b>Bathroom</b> - Bathtub or shower, free toiletries, and a hair dryer</p><p><b>Practical</b> - Laptop workspace and phone</p><p><b>Comfort</b> - Air conditioning and daily housekeeping</p><p><b>Accessibility</b> - Raised toilet seat and grab bar near toilet</p><p>Non-Smoking</p>',
#    'details': {'amenities': ['Air conditioning',
#      'Bathtub or shower',
#      'Bedsheets provided',
#      'Daily housekeeping',
#      'Desk',
#      'Free toiletries',
#      'Free WiFi',
#      'Grab bar - near toilet',
#      'Hair dryer',
#      'Laptop-friendly workspace',
#      'Phone',
#      'Raised toilet seat',
#      'Refrigerator',
#      'Television',
#      'Towels provided']}},
#   'bedChoices': {'extraBedTypes': [], 'mainOptions': ['1 Queen Bed']},
# ...

# %%
# of

# %%
import requests

url = "https://hotels4.p.rapidapi.com/locations/v2/search"

querystring = {"query":"New York, Manhattan View Hotel","locale":"en_US","currency":"USD"}

headers = {
    'x-rapidapi-host': "hotels4.p.rapidapi.com",
    'x-rapidapi-key': "9bd3146f2fmsh683867edab2caa3p13a885jsn3ee24bfa5443"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

# %%
import pandas as pd
import datetime
from datetime import date,timedelta

today = date.today()
out = today+timedelta(days=1)
check_in = today.strftime("%Y-%m-%d")
check_out = out.strftime("%Y-%m-%d")

def saveHotelID(response,hotel_name,geo_pair):
  total = response.json()
  print(total, hotel_name, geo_pair)
  total = total["suggestions"]
  hotel = [e for e in total if e['group']=='HOTEL_GROUP'][0]
  if len(hotel["entities"]) == 0:
    print("Can't find hotel when name: ", hotel_name)
    return
  all_hotel = hotel["entities"]
  ID = []
  name = []
  geometric = []
  Find = False
  for h in all_hotel:
    ID.append(h["destinationId"])
    name.append(h["name"])
    geometric.append((float("{:.3f}".format(h["latitude"])),float("{:.3f}".format(h["longitude"]))))
    if h["name"] == hotel_name or geometric[-1] == geo_pair:
      Find = True
  hotel_info = pd.DataFrame({"ID":ID, "name":name, "geometric": geometric})
  return Find, hotel_info

def saveHotelPrice(total,hotel_name):
  #total = response.json()["price"]
  rooms = total["body"]["roomsAndRates"]["rooms"]
  room_name = []
  pricelst=[]
  h_name = []
  for room in rooms:
    n = room["name"]
    price = room["ratePlans"][0]["price"]['fullyBundledPricePerStay']
    h_name.append(hotel_name)
    room_name.append(n)
    pricelst.append(price)
  price_df = pd.DataFrame({"name": h_name,"Room_type":room_name,"Price":pricelst})
  return price_df

# %%
import pandas as pd
import datetime
from datetime import date,timedelta

today = date.today()
out = today+timedelta(days=1)
check_in = today.strftime("%Y-%m-%d")
check_out = out.strftime("%Y-%m-%d")

def saveHotelID(response,hotel_name,geo_pair):
  total = response.json()
  print(total, hotel_name, geo_pair)
  total = total["suggestions"]
  hotel = [e for e in total if e['group']=='HOTEL_GROUP'][0]
  if len(hotel["entities"]) == 0:
    print("Can't find hotel when name: ", hotel_name)
    return
  all_hotel = hotel["entities"]
  ID = []
  name = []
  geometric = []
  Find = False
  for h in all_hotel:
    ID.append(h["destinationId"])
    name.append(h["name"])
    geometric.append((float("{:.3f}".format(h["latitude"])),float("{:.3f}".format(h["longitude"]))))
    if h["name"] == hotel_name or geometric[-1] == geo_pair:
      Find = True
  hotel_info = pd.DataFrame({"ID":ID, "name":name, "geometric": geometric})
  return Find, hotel_info

def saveHotelPrice(total,hotel_name):
  #total = response.json()["price"]
  rooms = total["body"]["roomsAndRates"]["rooms"]
  room_name = []
  pricelst=[]
  h_name = []
  for room in rooms:
    n = room["name"]
    price = room["ratePlans"][0]["price"]['fullyBundledPricePerStay']
    h_name.append(hotel_name)
    room_name.append(n)
    pricelst.append(price)
  price_df = pd.DataFrame({"name": h_name,"Room_type":room_name,"Price":pricelst})
  return price_df
  
def getresponse(hotel_name):

  url = "https://hotels4.p.rapidapi.com/locations/v2/search"

  querystring = {"query":"New York,"+hotel_name,"locale":"en_US","currency":"USD"}
  headers = {
      'x-rapidapi-host': "hotels4.p.rapidapi.com",
      'x-rapidapi-key': "9bd3146f2fmsh683867edab2caa3p13a885jsn3ee24bfa5443"
      }

  response = requests.request("GET", url, headers=headers, params=querystring)
  return response

def getresponse2(id,checkIn, checkOut):

  url = "https://hotels4.p.rapidapi.com/properties/get-details"

  querystring = {"id":id,"checkIn":checkIn,"checkOut":checkOut,"adults1":"1","currency":"USD","locale":"en_US"}

  headers = {
      'x-rapidapi-host': "hotels4.p.rapidapi.com",
      'x-rapidapi-key': "9bd3146f2fmsh683867edab2caa3p13a885jsn3ee24bfa5443"
      }

  response = requests.request("GET", url, headers=headers, params=querystring)
  return response

def getAllPrice(df,checkIn, checkOut):
  price_df = pd.DataFrame()
  for i in range(len(df)):
    element = df.iloc[i]
    h_id = element["geoID"]
    h_name = element["name"]
    response = getresponse2(h_id, checkIn, checkOut)
    try:
      total = response.json()["data"]
      print("get json")
    except:
      print("cant find json:", h_id, h_name)
      continue
    tmp_price = saveHotelPrice(total,h_name)
    print(tmp_price)
    if price_df.empty:
      price_df = tmp_price
    else:
      price_df = pd.concat([price_df, tmp_price])
    print("Total price:", price_df)
  return price_df

def getID(df,hotel_info):
  df["geoID"] = [None for _ in range(len(df))]
  for i in range(len(df)):
    element = df.iloc[i]
    h_name = element["name"]
    h_geo = (float("{:.3f}".format(element["geometry_location_lat"])), float("{:.3f}".format(element["geometry_location_lng"])))
    print(h_name,h_geo)
    if hotel_info.empty:
      response = getresponse(h_name)
      Find, new_hotel_info = saveHotelID(response,h_name,h_geo)
      if Find:
        if (h_name in list(new_hotel_info["name"])):
          df["geoID"].iloc[i].loc[i] = new_hotel_info[new_hotel_info["name"] == h_name]["ID"].iloc[0]
        elif h_geo in list(hotel_info["geometric"]):
          df["geoID"].iloc[i].loc[i]= new_hotel_info[new_hotel_info["geometric"] == h_geo]["ID"].iloc[0]
      hotel_info = new_hotel_info
    else:
      print("have hotel")
      if (h_name in list(hotel_info["name"])):
        print("Find same name")
        df["geoID"].iloc[i] = hotel_info[hotel_info["name"] == h_name]["ID"].iloc[0]
      elif h_geo in list(hotel_info["geometric"]):
        print("Find same geo")
        df["geoID"].iloc[i] = hotel_info[hotel_info["geometric"] == h_geo]["ID"].iloc[0]
      else:
        response = getresponse(h_name)
        Find, new_hotel_info = saveHotelID(response,h_name,h_geo)
        if Find:
          if (h_name in list(new_hotel_info["name"])):
            df["geoID"].iloc[i] = new_hotel_info[new_hotel_info["name"] == h_name]["ID"].iloc[0]
          elif h_geo in list(hotel_info["geometric"]):
            df["geoID"].iloc[i] = new_hotel_info[new_hotel_info["geometric"] == h_geo]["ID"].iloc[0]
        hotel_info = pd.concat([hotel_info, new_hotel_info]).drop_duplicates("name")
  return df, hotel_info

# %%
df
# Out:
#   business_status  ...       geoID
# 0     OPERATIONAL  ...  1168574848
# 1     OPERATIONAL  ...        None
# 2     OPERATIONAL  ...      114218
# 3     OPERATIONAL  ...  2140897664
#
# [4 rows x 22 columns]

# %%
price_df = getAllPrice(df,check_in, check_out)
# Out:
# get json
#                    name  ...       Price
# 0  Manhattan View Hotel  ...  total $103
# 1  Manhattan View Hotel  ...  total $109
# 2  Manhattan View Hotel  ...  total $121
# 3  Manhattan View Hotel  ...  total $157
# 4  Manhattan View Hotel  ...  total $230
#
# [5 rows x 3 columns]
# Total price:                    name  ...       Price
# 0  Manhattan View Hotel  ...  total $103
# 1  Manhattan View Hotel  ...  total $109
# 2  Manhattan View Hotel  ...  total $121
# 3  Manhattan View Hotel  ...  total $157
# 4  Manhattan View Hotel  ...  total $230
#
# [5 rows x 3 columns]
# cant find json: None TBA Time Square
# get json
#                  name  ...         Price
# 0  Park Lane New York  ...    total $731
# 1  Park Lane New York  ...    total $754
# 2  Park Lane New York  ...    total $869
# 3  Park Lane New York  ...    total $869
# 4  Park Lane New York  ...  total $1,420
# 5  Park Lane New York  ...  total $1,594
#
# [6 rows x 3 columns]
# ...

# %%
price_df
# Out:
#                        name  ...         Price
# 0      Manhattan View Hotel  ...    total $103
# 1      Manhattan View Hotel  ...    total $109
# 2      Manhattan View Hotel  ...    total $121
# 3      Manhattan View Hotel  ...    total $157
# 4      Manhattan View Hotel  ...    total $230
# 0        Park Lane New York  ...    total $731
# 1        Park Lane New York  ...    total $754
# 2        Park Lane New York  ...    total $869
# 3        Park Lane New York  ...    total $869
# 4        Park Lane New York  ...  total $1,420
# 5        Park Lane New York  ...  total $1,594
# 0  Pestana CR7 Times Square  ...    total $283
# 1  Pestana CR7 Times Square  ...    total $305
# 2  Pestana CR7 Times Square  ...    total $310
# 3  Pestana CR7 Times Square  ...    total $364
# 4  Pestana CR7 Times Square  ...    total $391
#
# [16 rows x 3 columns]

# %%
response.json()["data"]["body"]["roomsAndRates"]["rooms"]
# Out:
# [{'additionalInfo': {'description': '<p><strong>1 King Bed</strong></p><p>350 sq feet </p><br/><p><b>Internet</b> - Free WiFi (6-device limit) </p><p><b>Entertainment</b> - 30-inch flat-screen TV with cable channels</p><p><b>Food & Drink</b> - 24-hour room service</p><p><b>Sleep</b> - Hypo-allergenic bedding, blackout drapes/curtains, turndown service, and bed sheets </p><p><b>Bathroom</b> - Private bathroom, shower/tub combination, free toiletries, and a hair dryer</p><p><b>Practical</b> - Free international calls, safe, and free weekday newspaper</p><p><b>Comfort</b> - Air conditioning and daily housekeeping</p><p><b>Accessibility</b> - Visual fire alarm and braille signage</p><p><b>Eco-friendly</b> - Recycling bin</p><p>Non-Smoking</p><p>Connecting/adjoining rooms can be requested, subject to availability </p>',
#    'details': {'amenities': ['Air conditioning',
#      'Bedsheets provided',
#      'Blackout drapes/curtains',
#      'Braille signage',
#      'Cable TV service',
# ...

# %%
rooms = p["body"]["roomsAndRates"]["rooms"]
room_name = []
pricelst=[]
for room in rooms:
  n = room["name"]
  price = room["ratePlans"][0]["price"]['fullyBundledPricePerStay']
  room_name.append(n)
  pricelst.append(price)

# %%
room_name
# Out:
# ['Room, 1 King Bed (Park Lane)',
#  'Room, 1 King Bed, City View',
#  'Room, 2 Queen Beds, City View',
#  'Room, 2 Queen Beds, Accessible, City View (Roll-In Shower)',
#  'Panoramic Room, 2 Queen Beds, Park View',
#  'Suite, 1 Bedroom, City View']

# %%
room_name
# Out:
# ['Room, 1 King Bed (Park Lane)',
#  'Room, 1 King Bed, City View',
#  'Room, 2 Queen Beds, City View',
#  'Room, 2 Queen Beds, Accessible, City View (Roll-In Shower)',
#  'Panoramic Room, 2 Queen Beds, Park View',
#  'Suite, 1 Bedroom, City View']

# %%
pricelst
# Out:
# ['total $731',
#  'total $754',
#  'total $869',
#  'total $869',
#  'total $1,420',
#  'total $1,594']

# %%
room_name
# Out:
# ['Comfort Room, 1 King Bed',
#  'Comfort Room, 1 King Bed (Plus)',
#  'Comfort Double Room',
#  'Superior Room, 1 King Bed',
#  'Superior Double Room']

# %%
pricelst
# Out:
# ['total $283', 'total $305', 'total $310', 'total $364', 'total $391']

# %%
df, new_hotel = getID(df, hotel_info)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
new_hotel
# Out:
#            ID  ...           update_geo
# 0  1168574848  ...  (40.7577, -73.9385)
# 1      480987  ...  (40.7502, -73.9367)
# 2      400299  ...   (40.7498, -73.952)
# 3   525894624  ...  (40.7484, -73.9398)
# 4      324875  ...   (40.756, -73.9414)
# 5   419429440  ...  (40.7499, -73.9377)
# 0  1478700992  ...  (40.7566, -73.9927)
# 0      114218  ...                  NaN
# 1  1154520480  ...                  NaN
# 0  2140897664  ...                  NaN
#
# [10 rows x 4 columns]

# %%
df
# Out:
#   business_status  ...       geoID
# 0     OPERATIONAL  ...  1168574848
# 1     OPERATIONAL  ...        None
# 2     OPERATIONAL  ...      114218
# 3     OPERATIONAL  ...  2140897664
#
# [4 rows x 22 columns]

# %%
hotel_info
# Out:
#            ID  ...           update_geo
# 0  1168574848  ...  (40.7577, -73.9385)
# 1      480987  ...  (40.7502, -73.9367)
# 2      400299  ...   (40.7498, -73.952)
# 3   525894624  ...  (40.7484, -73.9398)
# 4      324875  ...   (40.756, -73.9414)
# 5   419429440  ...  (40.7499, -73.9377)
# 0  1168574848  ...  (40.7577, -73.9385)
# 1      480987  ...  (40.7502, -73.9367)
# 2      400299  ...   (40.7498, -73.952)
# 3   525894624  ...  (40.7484, -73.9398)
# 4      324875  ...   (40.756, -73.9414)
# 5   419429440  ...  (40.7499, -73.9377)
# 0  1478700992  ...  (40.7566, -73.9927)
#
# [13 rows x 4 columns]

# %%
import pandas_gbq
data_frame = pandas_gbq.read_gbq(
    "SELECT * FROM `finalproject.Hotel_info`",
    project_id="big-data-6893-326923")
# Out:
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas_gbq/gbq.py in _download_results(self, query_job, max_results, progress_bar_type)
#     549
# --> 550             query_job.result()
#     551             # Get the table schema, so that we can list rows.
#
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/job.py in result(self, timeout, page_size, retry, max_results)
#    2973         try:
# -> 2974             super(QueryJob, self).result(timeout=timeout)
#    2975
#
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/job.py in result(self, timeout, retry)
#     767         # TODO: modify PollingFuture so it can pass a retry argument to done().
# --> 768         return super(_AsyncJob, self).result(timeout=timeout)
#     769
#
# ...

# %%
df = data_frame.iloc[:4]
df
# Out:
#   business_status  ... plus_code_global_code
# 0     OPERATIONAL  ...           87G8Q356+3J
# 1     OPERATIONAL  ...           87G8Q244+JW
# 2     OPERATIONAL  ...           87G8Q28F+2V
# 3     OPERATIONAL  ...           87G8Q244+9P
#
# [4 rows x 21 columns]

# %%
data_frame
# Out:
#    business_status  ... plus_code_global_code
# 0      OPERATIONAL  ...           87G8Q356+3J
# 1      OPERATIONAL  ...           87G8Q244+JW
# 2      OPERATIONAL  ...           87G8Q28F+2V
# 3      OPERATIONAL  ...           87G8Q244+9P
# 4      OPERATIONAL  ...           87G8Q25G+53
# 5      OPERATIONAL  ...           87G8Q227+WQ
# 6      OPERATIONAL  ...           87G8Q346+6X
# 7      OPERATIONAL  ...           87G8R3R6+2R
# 8      OPERATIONAL  ...           87G8Q267+MV
# 9      OPERATIONAL  ...           87G8Q355+42
# 10     OPERATIONAL  ...           87G8Q256+FJ
# 11     OPERATIONAL  ...           87G8Q355+54
# 12     OPERATIONAL  ...           87G8Q246+2Q
# 13     OPERATIONAL  ...           87G8Q356+M2
# 14     OPERATIONAL  ...           87G8Q388+JG
# 15     OPERATIONAL  ...           87G8Q2C9+8Q
# 16     OPERATIONAL  ...           87G8R3J9+M9
# 17     OPERATIONAL  ...           87G8Q337+QQ
# 18     OPERATIONAL  ...           87G7QX5G+GM
# ...

# %%
element["geoID"] = hotel_info[hotel_info["name"] == element["name"]]["ID"].iloc[0]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
tmp_df["geoID"].iloc[0] = hotel_info[hotel_info["name"] == element["name"]]["ID"].iloc[0]
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
element
# Out:
# business_status                                                          OPERATIONAL
# formatted_address                                    37-35 21st St, Queens, NY 11101
# icon                               https://maps.gstatic.com/mapfiles/place_api/ic...
# icon_background_color                                                        #909CE1
# icon_mask_base_uri                 https://maps.gstatic.com/mapfiles/place_api/ic...
# name                                                            Manhattan View Hotel
# photos                             [{'height': 4000, 'html_attributions': ['<a hr...
# place_id                                                 ChIJq20bjNJYwokRWik5S8D4TsU
# rating                                                                             3
# reference                                                ChIJq20bjNJYwokRWik5S8D4TsU
# types                              ['lodging', 'point_of_interest', 'establishment']
# ...

# %%
import numpy as np
df[df["geoID"] == "None"]
# Out:
# Empty DataFrame
# Columns: [business_status, formatted_address, icon, icon_background_color, icon_mask_base_uri, name, photos, place_id, rating, reference, types, user_ratings_total, geometry_location_lat, geometry_location_lng, geometry_viewport_northeast_lat, geometry_viewport_northeast_lng, geometry_viewport_southwest_lat, geometry_viewport_southwest_lng, opening_hours_open_now, plus_code_compound_code, plus_code_global_code, geoID]
# Index: []

# %%
df["geoID"].iloc[1]

# %%
tmp_df
# Out:
#   business_status  ...       geoID
# 0     OPERATIONAL  ...  1168574848
# 1     OPERATIONAL  ...        None
# 2     OPERATIONAL  ...        None
#
# [3 rows x 22 columns]

# %%
hotel_info
# Out:
#            ID  ...                geometric
# 0  1168574848  ...      (40.7577, -73.9385)
# 1      480987  ...    (40.75022, -73.93669)
# 2      400299  ...  (40.749821, -73.952007)
# 3   525894624  ...    (40.74844, -73.93984)
# 4      324875  ...  (40.756041, -73.941364)
# 5   419429440  ...  (40.749853, -73.937682)
#
# [6 rows x 3 columns]

# %%
Find
# Out:
# True

# %%
hotel_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df
# Out:
#   business_status  ... plus_code_global_code
# 0     OPERATIONAL  ...           87G8Q356+3J
# 1     OPERATIONAL  ...           87G8Q244+JW
#
# [2 rows x 21 columns]

# %%
import pandas_gbq
data_frame = pandas_gbq.read_gbq(
    "SELECT * FROM `Hotel_10025_5000`",
    project_id="big-data-6893-326923")
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=725825577420-unm2gnkiprugilg743tkbig250f4sfsj.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fbigquery&state=zNyZDpWyKBudpmab0zQijIfehrblMF&prompt=consent&access_type=offline
# Enter the authorization code: 4/1AX4XfWjeVjJYDSYDQ7Y--MzK48VCvQUN8Bf6QurbEL0DlU52TOVMqSIQJsc
# Downloading: 100%|██████████| 226/226 [00:00<00:00, 1037.48rows/s]

# %%
data_frame
# Out:
#                                                   name  ...       Price
# 0    Hilton Garden Inn New York/Central Park South-...  ...  total $223
# 1    Hilton Garden Inn New York/Central Park South-...  ...  total $223
# 2    Hilton Garden Inn New York/Central Park South-...  ...  total $223
# 3    Hilton Garden Inn New York/Central Park South-...  ...  total $233
# 4    Hilton Garden Inn New York/Central Park South-...  ...  total $244
# ..                                                 ...  ...         ...
# 221                                     YOTEL New York  ...  total $405
# 222                                     YOTEL New York  ...  total $408
# 223                                     YOTEL New York  ...  total $486
# 224                                     YOTEL New York  ...  total $537
# 225                                     YOTEL New York  ...  total $601
#
# [226 rows x 3 columns]

# %%
update_price = [int(p.split(" ")[1][1:].replace(",","")) for p in data_frame["Price"]]

# %%
data_frame["updatePrice"] = update_price

# %%
data_frame[:15]
# Out:
#                                                  name  ... updatePrice
# 0   Hilton Garden Inn New York/Central Park South-...  ...         223
# 1   Hilton Garden Inn New York/Central Park South-...  ...         223
# 2   Hilton Garden Inn New York/Central Park South-...  ...         223
# 3   Hilton Garden Inn New York/Central Park South-...  ...         233
# 4   Hilton Garden Inn New York/Central Park South-...  ...         244
# 5   Hilton Garden Inn New York/Central Park South-...  ...         264
# 6   Hilton Garden Inn New York/Central Park South-...  ...         264
# 7   Hilton Garden Inn New York/Central Park South-...  ...         264
# 8   Hilton Garden Inn New York/Central Park South-...  ...         285
# 9   Hilton Garden Inn New York/Central Park South-...  ...         285
# 10  Hilton Garden Inn New York/Central Park South-...  ...         295
# 11  Hilton Garden Inn New York/Central Park South-...  ...         295
# ...

# %%
update_roomType = []
update_name = []
update_price = []
for i in range(len(data_frame)):
  room_type = data_frame.iloc[i]["Room_type"]
  name = data_frame.iloc[i]["name"]
  price = data_frame.iloc[i]["updatePrice"]

  if "Suite" in room_type:
    update_roomType.append("Suite")
    update_name.append(name)
    update_price.append(price)
  elif "King" in room_type:
    update_roomType.append("King")
    update_name.append(name)
    update_price.append(price)
  elif "Queen" in room_type:
    update_roomType.append("Queen")
    update_name.append(name)
    update_price.append(price)
  elif "Double" in room_type:
    update_roomType.append("Double")
    update_name.append(name)
    update_price.append(price)
  else:
    print(room_type, data_frame.iloc[i]["Price"])
    # update_roomType.append(room_type)
# Out:
# Room, Non Smoking total $354
# Deluxe Room, Multiple Beds total $264
# Studio with two twin beds total $163
# Apartment, 2 Bedrooms, Kitchenette total $343
# Deluxe Room, 2 Twin Beds, Multiple View (Tryp Twin) total $269
# Standard Room total $315
# Deluxe Room, Multiple Beds, Non Smoking total $279
# Standard Room total $259
# Standard Twin Room, 2 Twin Beds, Non Smoking total $238
# Family Room (Tryp) total $375
# Family Room (Tryp) total $398
# Standard Room total $315
# Room, Multiple Beds, Refrigerator total $208
# Room, Multiple Beds, Non Smoking total $301
# Premium Room, Multiple Beds (With Bunk) total $345

# %%
import pandas as pd
update_df = pd.DataFrame({"name": update_name, "Type":update_roomType, "Price": update_price})

# %%
update_df
# Out:
#                                                   name   Type  Price
# 0    Hilton Garden Inn New York/Central Park South-...   King    223
# 1    Hilton Garden Inn New York/Central Park South-...   King    223
# 2    Hilton Garden Inn New York/Central Park South-...  Queen    223
# 3    Hilton Garden Inn New York/Central Park South-...   King    233
# 4    Hilton Garden Inn New York/Central Park South-...   King    244
# ..                                                 ...    ...    ...
# 206                                     YOTEL New York  Queen    405
# 207                                     YOTEL New York  Queen    408
# 208                                     YOTEL New York  Suite    486
# 209                                     YOTEL New York  Suite    537
# 210                                     YOTEL New York  Suite    601
#
# [211 rows x 3 columns]

# %%
update_df.groupby(["name","Type"]).min("Price").reset_index()
# Out:
#                                                   name    Type  Price
# 0                           Ameritania at Times Square  Double    264
# 1                           Ameritania at Times Square    King    223
# 2                           Ameritania at Times Square   Queen    223
# 3                           Ameritania at Times Square   Suite    431
# 4                                         Arlo Midtown  Double    332
# ..                                                 ...     ...    ...
# 98                 Wingate by Wyndham Long Island City  Double    232
# 99                 Wingate by Wyndham Long Island City    King    220
# 100  Wingate by Wyndham New York Midtown South/5th Ave  Double    245
# 101                                     YOTEL New York   Queen    265
# 102                                     YOTEL New York   Suite    442
#
# [103 rows x 3 columns]

# %%
len(data_frame["name"].drop_duplicates())
# Out:
# 42

# %%
len(update_df["name"].drop_duplicates())
# Out:
# 42

# %%
check_in = "2021-12-05"
project_id = 'big-data-6893-326923'

price_dfname = "finalproject.HotelPrice_"+check_in

query = "SELECT * FROM `"+price_dfname+"`"
print(price_dfname)
price_df = pandas_gbq.read_gbq(
    query,
    project_id=project_id)
# Out:
# finalproject.HotelPrice_2021-12-05
# Downloading: 100%|██████████| 226/226 [00:00<00:00, 1361.03rows/s]
